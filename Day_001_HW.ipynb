# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $

# %% [markdown]
# # [作業重點]
# - 注意程式的縮排
# - 是否能將數學公式, 轉換為 Python 的函式組合? (In[2], Out[2])

# %%
# 載入基礎套件與代稱
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_absolute_error(y, y_hat):
    """
    for i in range(len(y)):
        mae = mae + abs(y[i]-y_hat[i])
    
    mae =(1/len(y))*mae
    """
    mae = sum(abs(y - y_hat)) / len(y)
    return mae

# %%
def mean_squared_error(y,y_hat):
    """
    計算 MAE
    mse = 0
    for i in range(len(y)):
        mse = mse+(y[i]-y_hat[i])**2
        
    mse =(1/len(y))*mse
    """
    
    mse = sum((y-y_hat)**2)/len(y)            
    return mse

# %%
w = 3
b = 0.5
x_lin = np.linspace(0, 200, 201)
y = (x_lin + np.random.randn(201) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
# 與範例相同, 不另外解說
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'g.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

"""
Colors: 
Blue:  b
Red:   r
Green: g
Black: k
Yellow:y
White: w
"""

# %%
# 執行 Function, 確認有沒有正常執行
mse = mean_squared_error(y, y_hat)
mae = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (mse))
print("The Mean absolute error is %.3f" % (mae))
# Out:
# The Mean squared error is 192.608
# The Mean absolute error is 10.575

# %% [markdown]
# # [Q2]
#
# 請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：
#
# 1. 你選的這組資料為何重要
# 2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
# 3. 蒐集而來的資料型態為何
# 4. 這組資料想解決的問題如何評估
#
#
# # [Q3]
#
# 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
#
# 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
#
# 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
#
# 3. 蒐集而來的資料型態為何
#
# 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)

# %%
# [Q2]
1. The topic that I had selected is based on Seattle Airbnb Open Data. I chose this dataset due to wanting to find out
how COVID had affected the AirBnB sector in the current time, although the original time was from 2008.

2. The dataset is a part of AirBnB Inside

3. 資料分為3個檔案，Calendar(入租日期), Listing(房屋ID), Review (售後服務)

CSV黨變數:    
Calendar.csv Tags: listing_id, date, available, price, scrape_id, last_scrape
Listing.csv  Tags: id, listing_url, scrape_id, last_scraped, name, city, bathrooms ...  (高達92種，就不一一提出所有tags)
Review.csv   Tags: listing_id, id, date, reviewer_id, reviewer_name, comment

4. 目標: 預測 Seattle AirBnB rental price，根據資料的交叉比對，運用 MSE (Mean square Error)來找出價格預判
    
    
# [Q3]
1. a)載客熱區，根據載客熱區，可以提前判斷最優畫行車路徑，藉此提高效率以提升業績
   b)以車隊的整體營收，來定義業績
   c)天氣(雨，大熱天)、地域性(交通便利性、市中心、鄉村)

2. 資料來源：車隊計程車GPS定位系統及行車紀錄器影像
   整合車隊之自動記錄 (時間、地點、天氣、付款金額)，系統設定 (車款、車齡), 
   Method (apps, in-company phone system)

3. 蒐集而來的資料型態主要會以文字，數字敘述

4. 調整車隊的配置，安排每位司機限定於某區域，方便預判行車路徑，看整體業績是否有提升。
